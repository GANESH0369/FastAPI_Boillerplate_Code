# %% [markdown]
# <a href="https://colab.research.google.com/github/GANESH0369/FastAPI_Boillerplate_Code/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd7282b5-47a4-4fc7-86e8-1da9f3778993" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd7282b5-47a4-4fc7-86e8-1da9f3778993">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
mydata = data[data['PaymentMethod'] == 'UPI']
mydata
# Out:
#      OrderID        Date  CustomerID CustomerName   Product     Category  \
# 2          3  2024-02-17        2640          Raj    Tablet  Electronics
# 3          4  2024-01-27        3798         Sita    Laptop  Electronics
# 4          5  2024-08-12        2309         Anil    Tablet  Electronics
# 9         10  2024-08-17        3750        Kavya    Mobile  Electronics
# 14        15  2024-02-13        2652       Vikram    Laptop  Electronics
# ..       ...         ...         ...          ...       ...          ...
# 985      986  2024-12-11        4651         Anil  Keyboard  Accessories
# 987      988  2024-06-22        4376         Anil  Keyboard  Accessories
# 990      991  2024-10-01        4998        Kavya     Mouse  Accessories
# 993      994  2024-06-12        2422       Vikram   Monitor  Electronics
# 998      999  2024-06-14        3964        Meena     Mouse  Accessories
#
#     Region SalesPerson PaymentMethod  Quantity  Price  Discount(%)  Tax(%)  \
# ...

# %%
# Out:
# 1000

# %%
import pandas as pd

data = pd.read_excel("Enhanced_Sales_Analytics_Dataset.xlsx")
data.head()
# Out:
#    OrderID        Date  CustomerID CustomerName     Product     Category  \
# 0        1  2024-01-07        3707          Raj      Laptop  Electronics
# 1        2  2024-12-30        1237        Arjun  Headphones  Accessories
# 2        3  2024-02-17        2640          Raj      Tablet  Electronics
# 3        4  2024-01-27        3798         Sita      Laptop  Electronics
# 4        5  2024-08-12        2309         Anil      Tablet  Electronics
#
#   Region SalesPerson PaymentMethod  Quantity  Price  Discount(%)  Tax(%)  \
# 0   East       Priya    NetBanking         3  14200        14.35    8.39
# 1  North       Rahul    NetBanking        10  33246         4.97    6.88
# 2  North       Sneha           UPI         6  49932        15.31    5.40
# 3   West       Rahul           UPI         1  43704         7.48   16.57
# 4  South       Rahul           UPI         6   4688        16.58   17.36
#
#      Revenue    Profit
# 0   39548.15   4927.37
# 1  337673.19  62170.14
# ...

# %%
# Total number of rows
datarows = data.count()

datarows
# Out:
# OrderID          1000
# Date             1000
# CustomerID       1000
# CustomerName     1000
# Product          1000
# Category         1000
# Region           1000
# SalesPerson      1000
# PaymentMethod    1000
# Quantity         1000
# Price            1000
# Discount(%)      1000
# Tax(%)           1000
# Revenue          1000
# Profit           1000
# dtype: int64

# %%
# Total number of rows and shape[0] means==>rows  and shaps[1] means==>colums
datarows = data.shape[0]
datarows
# Out:
# 1000

# %%
# Total number of rows and shape[0] means==>rows  and shaps[1] means==>colums
datarows = data.shape[1]
datarows
# Out:
# 15

# %%
# to fide the datatype is nothing but

datatype = data.dtypes
datatype
# Out:
# OrderID            int64
# Date              object
# CustomerID         int64
# CustomerName      object
# Product           object
# Category          object
# Region            object
# SalesPerson       object
# PaymentMethod     object
# Quantity           int64
# Price              int64
# Discount(%)      float64
# Tax(%)           float64
# Revenue          float64
# Profit           float64
# dtype: object

# %%
# to Create a new column

newcolumn = data['Profit_Margin']= data['Profit'] / data['Revenue'] * 100
newcolumn
# Out:
# 0      12.459167
# 1      18.411334
# 2       9.721538
# 3      12.432860
# 4      10.289460
#          ...
# 995    14.371348
# 996    19.160493
# 997    14.318330
# 998    14.838027
# 999    17.936644
# Length: 1000, dtype: float64

# %%
sum(data["Revenue"])
# Out:
# 228042127.16

# %%
sum(data["Profit"])
# Out:
# 33395004.79

# %%
avg_discount = data["Discount(%)"].mean()
avg_discount
# Out:
# np.float64(10.15643)

# %%
avg_tax = data["Tax(%)"].mean()
avg_tax
# Out:
# np.float64(11.460959999999998)
